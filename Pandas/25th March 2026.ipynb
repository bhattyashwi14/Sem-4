# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("ipl-matches.csv")
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.groupby("Season")["WinningTeam"].apply(lambda x:x.value_counts().head(1))
# Out:
# Season
# 2007/08  Rajasthan Royals         13
# 2009     Delhi Daredevils         10
# 2009/10  Mumbai Indians           11
# 2011     Chennai Super Kings      11
# 2012     Kolkata Knight Riders    12
# 2013     Mumbai Indians           13
# 2014     Kings XI Punjab          12
# 2015     Mumbai Indians           10
# 2016     Sunrisers Hyderabad      11
# 2017     Mumbai Indians           12
# 2018     Chennai Super Kings      11
# 2019     Mumbai Indians           11
# 2020/21  Mumbai Indians           11
# 2021     Chennai Super Kings      11
# 2022     Gujarat Titans           12
# Name: WinningTeam, dtype: int64

# %%
df.groupby("WinningTeam")["Player_of_Match"].apply(lambda x:x.nunique())
# Out:
# WinningTeam
# Chennai Super Kings            39
# Deccan Chargers                19
# Delhi Capitals                 16
# Delhi Daredevils               39
# Gujarat Lions                   7
# Gujarat Titans                  9
# Kings XI Punjab                42
# Kochi Tuskers Kerala            4
# Kolkata Knight Riders          44
# Lucknow Super Giants            6
# Mumbai Indians                 43
# Pune Warriors                  11
# Punjab Kings                   10
# Rajasthan Royals               41
# Rising Pune Supergiant          7
# Rising Pune Supergiants         3
# Royal Challengers Bangalore    36
# Sunrisers Hyderabad            36
# Name: Player_of_Match, dtype: int64

# %%
new_df=pd.DataFrame()
new_df["Count"]=df["Venue"].value_counts().head(5)
new_df
# Out:
#                                            Count
# Venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49

# %%
df1=new_df.merge(df, on="Venue",how="inner")
df1
# Out:
#                                          Venue  Count       ID       City  \
# 0                                 Eden Gardens     77  1178422    Kolkata
# 1                                 Eden Gardens     77  1178418    Kolkata
# 2                                 Eden Gardens     77  1178410    Kolkata
# 3                                 Eden Gardens     77  1178404    Kolkata
# 4                                 Eden Gardens     77  1178401    Kolkata
# ..                                         ...    ...      ...        ...
# 319  Rajiv Gandhi International Stadium, Uppal     49   336024  Hyderabad
# 320  Rajiv Gandhi International Stadium, Uppal     49   336014  Hyderabad
# 321  Rajiv Gandhi International Stadium, Uppal     49   335999  Hyderabad
# 322  Rajiv Gandhi International Stadium, Uppal     49   335990  Hyderabad
# 323  Rajiv Gandhi International Stadium, Uppal     49   335988  Hyderabad
#
#            Date   Season MatchNumber                        Team1  \
# ...

# %%
df1.groupby("Venue")["WinningTeam"].apply(lambda x:x.value_counts().head(1))
# Out:
# Venue
# Eden Gardens                               Kolkata Knight Riders          45
# Feroz Shah Kotla                           Delhi Daredevils               23
# M Chinnaswamy Stadium                      Royal Challengers Bangalore    29
# Rajiv Gandhi International Stadium, Uppal  Sunrisers Hyderabad            20
# Wankhede Stadium                           Mumbai Indians                 42
# Name: WinningTeam, dtype: int64

# %%
# point table season wise
df2=pd.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2952\1960189349.py in ?()
#       1 # point table season wise
#       2 df2=pd.DataFrame()
# ----> 3 df2.set_index(df["Season"])
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6191
#    6192             if len(arrays[-1]) != len(self):
#    6193                 # check newest element against length of calling frame, since
#    6194                 # ensure_index_from_sequences would not raise for append=False.
# -> 6195                 raise ValueError(
#    6196                     f"Length mismatch: Expected {len(self)} rows, "
#    6197                     f"received array of length {len(arrays[-1])}"
#    6198                 )
#
# ValueError: Length mismatch: Expected 0 rows, received array of length 950
